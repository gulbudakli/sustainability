# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('sustainable_development_report_2023.csv')
data.head()
# Out:
#   country_code  country region  overall_score  goal_1_score  goal_2_score
# 0          FIN  Finland   OECD      86.760595       99.5750     60.886750  \
# 1          SWE   Sweden   OECD      85.981397       98.8885     63.074125
# 2          DNK  Denmark   OECD      85.683637       99.2155     71.025250
# 3          DEU  Germany   OECD      83.358447       99.5105     72.366000
# 4          AUT  Austria   OECD      82.280189       99.4510     73.067500
#
#    goal_3_score  goal_4_score  goal_5_score  goal_6_score  ...  goal_8_score
# 0     95.386385     97.169333      92.11125       94.3276  ...     86.789000  \
# 1     96.904000     99.761667      91.44025       95.0576  ...     84.966429
# 2     95.398500     99.339667      86.99800       90.7316  ...     87.562429
# 3     93.039357     97.162667      81.92025       88.4434  ...     86.967286
# 4     92.468000     97.914333      84.57925       92.1636  ...     83.274143
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = data.copy()
plt.figure(figsize = (10,40))
sns.set_theme(style="whitegrid")
sns.set_color_codes("pastel")
sns.barplot(data = df, x = 'overall_score', y = 'country')
#plt.xticks(rotation = 90)
plt.title('Countries Overall Sustainable Development Score')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('sustainable_development_report_2023.csv')

# Türkiye'yi kırmızı olarak işaretlemek için renkler listesini oluşturun
renkler = ['orange' if country != 'Türkiye' else 'red' for country in data['country']]
color='renkler'
# Veriyi sıralayın
sorted_data = data.sort_values(by='overall_score', ascending=False)

# Çubuk grafiğini çizin
plt.figure(figsize = (10,40))
sns.set_theme(style="whitegrid")
sns.barplot(data=sorted_data, x='overall_score', y='country', palette=renkler)
plt.title('Ülkelerin Genel Sürdürülebilir Kalkınma Skoru')
plt.xlabel('Sürdürülebilir Kalkınma Skoru')
plt.ylabel('Ülkeler')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('sustainable_development_report_2023.csv')

# Türkiye'yi kırmızı olarak işaretlemek için renkler listesini oluşturun
renkler = ['blue' if country != 'Türkiye' else 'red' for country in data['country']]

# Veriyi sıralayın
sorted_data = data.sort_values(by='overall_score', ascending=False)

# Yalnızca ilk N ülkeyi gösterme
N = 10  # İlk 10 ülkeyi göstermek için
sorted_data = sorted_data.head(N)

# Yatay barplot oluşturun
plt.figure(figsize=(10, 8))
sns.set_theme(style="whitegrid")
sns.barplot(data=sorted_data, x='overall_score', y='country', palette='pastel')
plt.title('Ülkelerin Genel Sürdürülebilir Kalkınma Skoru')
plt.xlabel('Sürdürülebilir Kalkınma Skoru')
plt.ylabel('Ülkeler')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('sustainable_development_report_2023.csv')

# En yüksek ve en düşük 5 overall_score'a sahip ülkeleri seçin
top_countries = data.nlargest(5, 'overall_score')
bottom_countries = data.nsmallest(5, 'overall_score')

# Türkiye'yi içeren alt küme
turkey_and_top_bottom = pd.concat([top_countries, bottom_countries, data[data['country'] == 'Türkiye']])

# Yatay barplot oluşturun
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")
sns.barplot(data=turkey_and_top_bottom, x='overall_score', y='country', palette='pastel')
plt.title('En Yüksek ve En Düşük 5 Sürdürülebilir Kalkınma Skoruna Sahip Ülkeler ve Türkiye')
plt.xlabel('Sürdürülebilir Kalkınma Skoru')
plt.ylabel('Ülkeler')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('sustainable_development_report_2023.csv')

# En yüksek ve en düşük 5 overall_score'a sahip ülkeleri seçin
top_countries = data.nlargest(5, 'overall_score')
bottom_countries = data.nsmallest(5, 'overall_score')

# Verileri overall_score'a göre sıralayın
sorted_data = data.sort_values(by='overall_score', ascending=False)

# Türkiye'nin indeksini alın
turkey_index = sorted_data[sorted_data['country'] == 'Türkiye'].index[0]

# Türkiye'yi en yüksek ve en düşük 5 ülkenin ortasına yerleştirin
top_bottom_middle_countries = pd.concat([sorted_data.iloc[:5], sorted_data.iloc[turkey_index:turkey_index+1], sorted_data.iloc[-5:]])

# Yatay barplot oluşturun
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")
sns.barplot(data=top_bottom_middle_countries, x='overall_score', y='country', palette='pastel')
plt.title('En Yüksek ve En Düşük 5 Sürdürülebilir Kalkınma Skoruna Sahip Ülkeler ve Türkiye')
plt.xlabel('Sürdürülebilir Kalkınma Skoru')
plt.ylabel('Ülkeler')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('sustainable_development_report_2023.csv')

# En yüksek ve en düşük 5 overall_score'a sahip ülkeleri seçin
top_countries = data.nlargest(5, 'overall_score')
bottom_countries = data.nsmallest(5, 'overall_score')

# Verileri overall_score'a göre sıralayın
sorted_data = data.sort_values(by='overall_score', ascending=False)

# Türkiye'nin indeksini alın
turkey_index = sorted_data[sorted_data['country'] == 'Türkiye'].index[0]

# Türkiye'yi en yüksek ve en düşük 5 ülkenin ortasına yerleştirin
top_bottom_middle_countries = pd.concat([sorted_data.iloc[:5], sorted_data.iloc[turkey_index:turkey_index+1], sorted_data.iloc[-5:]])

# Türkiye'nin rengini turuncu yapın
renkler = ['purple' if country != 'Türkiye' else 'orange' for country in top_bottom_middle_countries['country']]

# Yatay barplot oluşturun
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")
sns.barplot(data=top_bottom_middle_countries, x='overall_score', y='country', palette=renkler)
plt.title('En Yüksek ve En Düşük 5 Sürdürülebilir Kalkınma Skoruna Sahip Ülkeler ve Türkiye')
plt.xlabel('Sürdürülebilir Kalkınma Skoru')
plt.ylabel('Ülkeler')
plt.show()
